# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexxLai/ml0716/blob/master/house_price.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from urllib.request import urlretrieve
url = "https://github.com/AlexxLai/ml0716/raw/master/train.csv"
urlretrieve(url, "train.csv")
url = "https://github.com/AlexxLai/ml0716/raw/master/test.csv"
urlretrieve(url, "test.csv")
# Out:
# ('test.csv', <http.client.HTTPMessage at 0x7fd305761048>)

# %%
import pandas as pd
train_df = pd.read_csv("train.csv",encoding = "utf-8")
test_df = pd.read_csv("test.csv",encoding = "utf-8")

# %%
datas = pd.concat([train_df,test_df])
datas = datas.drop(["SalePrice","Id"],axis=1)
datas
# Out:
#       MSSubClass MSZoning  LotFrontage  ...  YrSold SaleType SaleCondition
# 0             60       RL         65.0  ...    2008       WD        Normal
# 1             20       RL         80.0  ...    2007       WD        Normal
# 2             60       RL         68.0  ...    2008       WD        Normal
# 3             70       RL         60.0  ...    2006       WD       Abnorml
# 4             60       RL         84.0  ...    2008       WD        Normal
# ...          ...      ...          ...  ...     ...      ...           ...
# 1454         160       RM         21.0  ...    2006       WD        Normal
# 1455         160       RM         21.0  ...    2006       WD       Abnorml
# 1456          20       RL        160.0  ...    2006       WD       Abnorml
# 1457          85       RL         62.0  ...    2006       WD        Normal
# 1458          60       RL         74.0  ...    2006       WD        Normal
#
# [2919 rows x 79 columns]

# %%
na = datas.isna().sum()
na[na != 0].sort_values(ascending=False)
# Out:
# PoolQC          2909
# MiscFeature     2814
# Alley           2721
# Fence           2348
# FireplaceQu     1420
# LotFrontage      486
# GarageFinish     159
# GarageYrBlt      159
# GarageQual       159
# GarageCond       159
# GarageType       157
# BsmtExposure      82
# BsmtCond          82
# BsmtQual          81
# BsmtFinType2      80
# BsmtFinType1      79
# MasVnrType        24
# MasVnrArea        23
# MSZoning           4
# BsmtFullBath       2
# BsmtHalfBath       2
# Utilities          2
# Functional         2
# Exterior2nd        1
# Exterior1st        1
# SaleType           1
# BsmtFinSF1         1
# BsmtFinSF2         1
# BsmtUnfSF          1
# Electrical         1
# KitchenQual        1
# GarageCars         1
# GarageArea         1
# TotalBsmtSF        1
# dtype: int64

# %%
datas = datas.drop(na[na > 1000].index, axis=1)
datas
# Out:
#       MSSubClass MSZoning  LotFrontage  ...  YrSold SaleType SaleCondition
# 0             60       RL         65.0  ...    2008       WD        Normal
# 1             20       RL         80.0  ...    2007       WD        Normal
# 2             60       RL         68.0  ...    2008       WD        Normal
# 3             70       RL         60.0  ...    2006       WD       Abnorml
# 4             60       RL         84.0  ...    2008       WD        Normal
# ...          ...      ...          ...  ...     ...      ...           ...
# 1454         160       RM         21.0  ...    2006       WD        Normal
# 1455         160       RM         21.0  ...    2006       WD       Abnorml
# 1456          20       RL        160.0  ...    2006       WD       Abnorml
# 1457          85       RL         62.0  ...    2006       WD        Normal
# 1458          60       RL         74.0  ...    2006       WD        Normal
#
# [2919 rows x 74 columns]

# %%
# One-Hot Encoding: 補類別
datas = pd.get_dummies(datas)
datas = pd.get_dummies(datas, columns=["MSSubClass"])
datas
# Out:
#       LotFrontage  LotArea  ...  MSSubClass_180  MSSubClass_190
# 0            65.0     8450  ...               0               0
# 1            80.0     9600  ...               0               0
# 2            68.0    11250  ...               0               0
# 3            60.0     9550  ...               0               0
# 4            84.0    14260  ...               0               0
# ...           ...      ...  ...             ...             ...
# 1454         21.0     1936  ...               0               0
# 1455         21.0     1894  ...               0               0
# 1456        160.0    20000  ...               0               0
# 1457         62.0    10441  ...               0               0
# 1458         74.0     9627  ...               0               0
#
# [2919 rows x 285 columns]

# %%
# 補數字缺失值
med = datas.median()
datas = datas.fillna(med)
datas
# Out:
#       LotFrontage  LotArea  ...  MSSubClass_180  MSSubClass_190
# 0            65.0     8450  ...               0               0
# 1            80.0     9600  ...               0               0
# 2            68.0    11250  ...               0               0
# 3            60.0     9550  ...               0               0
# 4            84.0    14260  ...               0               0
# ...           ...      ...  ...             ...             ...
# 1454         21.0     1936  ...               0               0
# 1455         21.0     1894  ...               0               0
# 1456        160.0    20000  ...               0               0
# 1457         62.0    10441  ...               0               0
# 1458         74.0     9627  ...               0               0
#
# [2919 rows x 285 columns]

# %%
x_train = datas.iloc[:len(train_df)]
y_train = train_df["SalePrice"]
x_predict = datas.iloc[len(train_df):]
predict_id = test_df["Id"]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
reg = RandomForestRegressor(n_estimators=75, max_depth=8)
# clf = RandomForestClassifier(random_state=0)
# params = {
#     "n_estimators":range(20, 100),
#     "max_depth":range(5, 10)
# }
# search = GridSearchCV(clf, params, cv="r2", n_jobs=-1) 還沒改好
reg.fit(x_train, y_train)
pre = reg.predict(x_predict)
result = pd.DataFrame({
    "Id":predict_id,
    "SalePrice":pre
})
result.to_csv("house_price_rf.csv", encoding="utf-8", index=False)
result
